# %%
import requests

# %%
datos= {
  "token_google": "eyJhbGciOiJSUzI1NiIsImtpZCI6IjU2NGZlYWNlYzNlYmRmYWE3MzExYjlkOGU3M2M0MjgxOGYyOTEyNjQiLCJ0eXAiOiJKV1QifQ.....dEjTDGt63_fow__sXldO0nSPJiSetPvUtY2Jg41fee19vgavPnARL7DltzJv-zlzDP-1fptPp_LvPp34z9bFzXvhqghcZ6J7JvGpd4qmLyW0GPVEel--NiuZUBgclgEJnemFk4Jm-vTknab52s3hwwH-hV_wETg86q9YGjoOIQMRyvoeB_WCGZCOSm0P_n6a4o9e5KJ3bft4ffqHSjaVXnTPLHG6_SGw87QAauFoo7T6c7lJo_VBRHVGKLMFQT27qnczNpqUnYrwZvgPLBNvKCcw1Z_ZZMG0W9LBu9Pisb5pPEDRL73sdt6ZkZG7TcjkF4LAoMsuz9a7TPxkYvXOxg",
  "jwt": "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJlbWFpbCI6ImFkYWxiZXJ0b21nMDdAZ21haWwuY29tIiwicGFzc3dvcmQiOiI3MDk5NDYyNDQ2NTEtOWs1NTduNnZoODNjdjZnNGhvc2thbWFjN2lmbGZuNDUuYXBwcy5nb29nbGV1c2VyY29udGVudC5jb20iLCJleHAiOjE3MzQ0Njg0MDV9.c6-EtbFzOxFKlhSsbMI2tdU39ffHM3vPriYwlLWbcJY",
  "client_id": "709946244651-9k557n6vh83cv6g4hoskamac7iflfn45.apps.googleusercontent.com"
}

# %%
url = "http://localhost:8000/crea_nuevo_usuario"

# %%
response = requests.post(f"{url}", json=datos)

# %%
response.json()
# Out:
# {'message': 'valor invalido Token expired, 1734468165 < 1734468332'}

# %%
response.status_code
# Out:
# 400
